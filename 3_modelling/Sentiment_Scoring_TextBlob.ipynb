# %% [markdown]
# # Sentiment Scoring using Textblob

# %%
# pip install -U textblob-de
# python -m textblob.download_corpora
from textblob_de import TextBlobDE as TextBlob
import pandas as pd

# %% [markdown]
# #### Load Data

# %%
yelp = pd.read_csv('../2_text_preprocessing/cleaned_data_yelp.csv')
yelp.head()
# Out:
#                                              Comment  Rating  \
# 0  ich habe mir  bewertungen zu  restaurants auf ...       5
# 1  das  joseph ist ein ziemlich neues israelische...       4
# 2  schalömchen scheiße haben wir uns heute kosche...       5
# 3  essen war allenfalls ok muss ich nicht nochmal...       2
# 4  waren auf  empfehlung dort und wurden nicht en...       5
#
#                                        Clean_Comment  \
# 0  ich habe mir  bewertungen zu  restaurants auf ...
# 1  das  joseph ist ein ziemlich neues israelische...
# 2  schalömchen scheiße haben wir uns heute kosche...
# 3  essen war allenfalls ok muss ich nicht nochmal...
# 4  waren auf  empfehlung dort und wurden nicht en...
#
#                                    Tokenized_Comment  \
# 0  bewertungen restaurants menulist angesehen res...
# 1  joseph ziemlich neues israelisches restaurant ...
# 2  schalömchen scheiße heute koscher weggeknallt ...
# 3  essen allenfalls ok nochmal insgesamt erlebnis...
# 4  empfehlung wurden enttäuscht hammer ambiente h...
#
#                                   Lemmatized_Comment
# 0  ich haben sich   bewertung zu   restaurant auf...
# 1  der   joseph sein ein ziemlich neu israelisch ...
# 2  schalömch scheiße haben wir sich heute kosch w...
# 3  essen sein allenfalls ok mussen ich nicht noch...
# 4  sein auf   empfehlung dort und werden nicht en...

# %% [markdown]
# #### Compute sentiment score per comment

# %%
def compute_sentiscore(text):
    blob=TextBlob(text)
    polarity = blob.sentiment.polarity
    return polarity
yelp['Senti_Blob'] = yelp['Lemmatized_Comment'].apply(lambda x: compute_sentiscore(x))

# %% [markdown]
# #### Scale Sentiblob to Rating Range 1-5

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(1,5))
# Create Array with specific dimension requirements to make scaler happy
senti_blob_ar= (yelp['Senti_Blob'].values).reshape(-1, 1)
Senti_Blob_scaled = pd.DataFrame(scaler.fit_transform(senti_blob_ar),columns=['Senti_norm'])
senti_blob = pd.DataFrame(yelp['Senti_Blob'])
yelp = pd.concat([yelp,Senti_Blob_scaled],axis=1)

# %% [markdown]
# #### Comparison Rating vs. TextBlob Sentiscore

# %%
Senti_Blob_scaled.plot.hist(grid=True, bins=5)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
yelp['Rating'].plot.hist(grid=True, bins=5)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
yelp.to_csv('yelp_cleaned_sentiscored.csv',header=True, index=False)
